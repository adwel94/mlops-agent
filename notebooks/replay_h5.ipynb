# %% [markdown]
# # replay_h5
#
# 저장된 에피소드의 액션을 SAPIEN 뷰어 창에서 재생한다. 별도 OS 창으로 뜬다.
#
# | 파라미터 | 설명 | 기본값 |
# |---|---|---|
# | `traj_path` | 재생할 궤적 .h5 경로 (옆에 `.json` 사이드카 필요) | (필수) |
# | `episode` | 재생할 에피소드 번호 | `0` |
# | `shader` | 렌더 셰이더 | `"default"` |
# | `blocking` | `True`면 창 닫을 때까지 대기, `False`면 백그라운드 | `False` |

# %%
import sys
from pathlib import Path
ROOT = Path.cwd().parent
if str(ROOT) not in sys.path:
    sys.path.insert(0, str(ROOT))

# %%
from scripts.replay_h5 import run

traj = ROOT / 'data' / 'datasets' / 'PickCube-v1' / 'trajectory.h5'
p = run(traj_path=str(traj), episode=0)
print('opened pid', p.pid)
# 닫기: p.terminate()

# %% [markdown]
# CLI: `python scripts/replay_h5.py --traj-path <h5> --episode 0`
