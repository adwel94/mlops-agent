# %% [markdown]
# # check_maniskill_env
#
# ManiSkill 설치/환경이 정상 동작하는지 점검한다 (핵심 import, CPU 시뮬, CPU 렌더). 파라미터 없음.
#
# 반환: `{"passed": bool, "checks": [...]}`.

# %%
import sys
from pathlib import Path
ROOT = Path.cwd().parent
if str(ROOT) not in sys.path:
    sys.path.insert(0, str(ROOT))

# %%
from scripts.check_maniskill_env import run

result = run()
print('passed:', result['passed'])
for c in result['checks']:
    print(' ', 'PASS' if c['passed'] else 'FAIL', c['name'], '-', c['detail'])

# %% [markdown]
# CLI: `python scripts/check_maniskill_env.py`
