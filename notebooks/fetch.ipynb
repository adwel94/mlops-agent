# %% [markdown]
# # Fetch Skill — Notebook Control
#
# 주어진 task의 공식 ManiSkill 데모를 Hugging Face에서 다운로드 (액션 공급원 "받아오기" 경로).
# **Idempotent**: 이미 받아져 있으면 스킵. `force=True` 시 재다운로드.
#
# 직접 액션을 생성하는 `solve`의 빠른 대안. 두 호출 패턴 검증:
# 1. Function mode — `from scripts.fetch import run`
# 2. Subprocess mode — 별도 프로세스 CLI 호출

# %% [markdown]
# ## Setup — import path

# %%
import sys
from pathlib import Path

PROJECT_ROOT = Path.cwd().parent
if str(PROJECT_ROOT) not in sys.path:
    sys.path.insert(0, str(PROJECT_ROOT))
print('project root:', PROJECT_ROOT)

# %% [markdown]
# ## ① Function mode — 이미 받아진 task (스킵 확인)

# %%
from scripts.fetch import run, is_downloaded

task = 'PickCube-v1'
print('downloaded before call?', is_downloaded(task))
out = run(task=task)
print('returned path:', out)
print('exists:', out.is_dir())

# %% [markdown]
# ## ② Subprocess mode — 동일 호출, 별도 프로세스

# %%
import subprocess, sys as _sys

result = subprocess.run(
    [_sys.executable, str(PROJECT_ROOT / 'scripts' / 'fetch.py'),
     '--task', 'PickCube-v1'],
    capture_output=True, text=True,
)
print('returncode:', result.returncode)
print(result.stdout.strip())

# %% [markdown]
# ## ③ 다운로드된 task 디렉토리 구조 확인

# %%
task_dir = Path.home() / '.maniskill' / 'demos' / 'PickCube-v1'
for sub in sorted(task_dir.iterdir()):
    if sub.is_dir():
        print(f'{sub.name}/')
        for f in sorted(sub.iterdir()):
            print(f'  {f.name:50s}  {f.stat().st_size / 1024:>10.1f} KB')
