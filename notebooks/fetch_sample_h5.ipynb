# %% [markdown]
# # fetch_sample_h5
#
# 공식 ManiSkill 데모 궤적(.h5)을 받아 프로젝트 `data/datasets/<task>/trajectory.h5` 로 저장한다.
#
# | 파라미터 | 설명 | 기본값 |
# |---|---|---|
# | `task` | 받을 태스크 이름. ManiSkill이 데모를 배포하는 태스크만 가능 | `"PickCube-v1"` |
# | `force` | 이미 있어도 다시 받기 | `False` |
#
# 반환: 저장된 `trajectory.h5` 경로.

# %%
import sys
from pathlib import Path
ROOT = Path.cwd().parent
if str(ROOT) not in sys.path:
    sys.path.insert(0, str(ROOT))

# %%
from scripts.fetch_sample_h5 import run

out = run(task='PickCube-v1')
print(out, '| exists:', out.exists())

# %% [markdown]
# CLI: `python scripts/fetch_sample_h5.py --task PickCube-v1`
